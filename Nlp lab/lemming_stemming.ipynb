# %%
with open('Pgm7StemLem.txt','r') as f:
  txt=f.read()
t=''.join(txt)
print(t)
# Out:
# Natural language processing refers to the branch of
# computer science and more specifically the branch of
# artificial intelligence, concerned with giving computers
# the ability to understand text and spoken words in much
# the same way human beings can. Human language is filled with
# ambiguities that make it incredibly difficult to write software
# that accurately determines the intended meaning of text or voice
# data. Homonyms, homophones,sarcasm, idioms, metaphors, grammar
# and usage exceptions,variations in sentence structure. These
# just a few of the irregularities of human language that take
# humans years to learn, but that programmers must teach natural
# language driven applications to recognize and understand
# accurately from the start if those applications are going to be
# useful.

# %%
# !pip install NLTK
# Out:
# Requirement already satisfied: NLTK in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from NLTK) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from NLTK) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from NLTK) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from NLTK) (4.66.6)

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
w=word_tokenize(t)
print(w)
# Out:
# ['Natural', 'language', 'processing', 'refers', 'to', 'the', 'branch', 'of', 'computer', 'science', 'and', 'more', 'specifically', 'the', 'branch', 'of', 'artificial', 'intelligence', ',', 'concerned', 'with', 'giving', 'computers', 'the', 'ability', 'to', 'understand', 'text', 'and', 'spoken', 'words', 'in', 'much', 'the', 'same', 'way', 'human', 'beings', 'can', '.', 'Human', 'language', 'is', 'filled', 'with', 'ambiguities', 'that', 'make', 'it', 'incredibly', 'difficult', 'to', 'write', 'software', 'that', 'accurately', 'determines', 'the', 'intended', 'meaning', 'of', 'text', 'or', 'voice', 'data', '.', 'Homonyms', ',', 'homophones', ',', 'sarcasm', ',', 'idioms', ',', 'metaphors', ',', 'grammar', 'and', 'usage', 'exceptions', ',', 'variations', 'in', 'sentence', 'structure', '.', 'These', 'just', 'a', 'few', 'of', 'the', 'irregularities', 'of', 'human', 'language', 'that', 'take', 'humans', 'years', 'to', 'learn', ',', 'but', 'that', 'programmers', 'must', 'teach', 'natural', 'language', 'driven', 'applications', 'to', 'recognize', 'and', 'understand', 'accurately', 'from', 'the', 'start', 'if', 'those', 'applications', 'are', 'going', 'to', 'be', 'useful', '.']

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
for i in w:
  print(i,'--->',ps.stem(i))
# Out:
# Natural ---> natur
# language ---> languag
# processing ---> process
# refers ---> refer
# to ---> to
# the ---> the
# branch ---> branch
# of ---> of
# computer ---> comput
# science ---> scienc
# and ---> and
# more ---> more
# specifically ---> specif
# the ---> the
# branch ---> branch
# of ---> of
# artificial ---> artifici
# intelligence ---> intellig
# , ---> ,
# concerned ---> concern
# with ---> with
# giving ---> give
# computers ---> comput
# the ---> the
# ability ---> abil
# to ---> to
# understand ---> understand
# text ---> text
# and ---> and
# spoken ---> spoken
# words ---> word
# in ---> in
# much ---> much
# the ---> the
# same ---> same
# way ---> way
# human ---> human
# beings ---> be
# can ---> can
# . ---> .
# Human ---> human
# language ---> languag
# is ---> is
# filled ---> fill
# with ---> with
# ambiguities ---> ambigu
# that ---> that
# make ---> make
# it ---> it
# incredibly ---> incred
# difficult ---> difficult
# to ---> to
# write ---> write
# software ---> softwar
# that ---> that
# accurately ---> accur
# determines ---> determin
# the ---> the
# intended ---> intend
# meaning ---> mean
# of ---> of
# text ---> text
# or ---> or
# voice ---> voic
# data ---> data
# . ---> .
# Homonyms ---> homonym
# , ---> ,
# homophones ---> homophon
# , ---> ,
# sarcasm ---> sarcasm
# , ---> ,
# idioms ---> idiom
# , ---> ,
# metaphors ---> metaphor
# , ---> ,
# grammar ---> grammar
# and ---> and
# usage ---> usag
# exceptions ---> except
# , ---> ,
# variations ---> variat
# in ---> in
# sentence ---> sentenc
# structure ---> structur
# . ---> .
# These ---> these
# just ---> just
# a ---> a
# few ---> few
# of ---> of
# the ---> the
# irregularities ---> irregular
# of ---> of
# human ---> human
# language ---> languag
# that ---> that
# take ---> take
# humans ---> human
# years ---> year
# to ---> to
# learn ---> learn
# , ---> ,
# but ---> but
# that ---> that
# programmers ---> programm
# must ---> must
# teach ---> teach
# natural ---> natur
# language ---> languag
# driven ---> driven
# applications ---> applic
# to ---> to
# recognize ---> recogn
# and ---> and
# understand ---> understand
# accurately ---> accur
# from ---> from
# the ---> the
# start ---> start
# if ---> if
# those ---> those
# applications ---> applic
# are ---> are
# going ---> go
# to ---> to
# be ---> be
# useful ---> use
# . ---> .

# %%
from nltk.stem.snowball import SnowballStemmer
sb=SnowballStemmer('english')
for i in w:
  print(i,'--->',sb.stem(i))
# Out:
# Natural ---> natur
# language ---> languag
# processing ---> process
# refers ---> refer
# to ---> to
# the ---> the
# branch ---> branch
# of ---> of
# computer ---> comput
# science ---> scienc
# and ---> and
# more ---> more
# specifically ---> specif
# the ---> the
# branch ---> branch
# of ---> of
# artificial ---> artifici
# intelligence ---> intellig
# , ---> ,
# concerned ---> concern
# with ---> with
# giving ---> give
# computers ---> comput
# the ---> the
# ability ---> abil
# to ---> to
# understand ---> understand
# text ---> text
# and ---> and
# spoken ---> spoken
# words ---> word
# in ---> in
# much ---> much
# the ---> the
# same ---> same
# way ---> way
# human ---> human
# beings ---> be
# can ---> can
# . ---> .
# Human ---> human
# language ---> languag
# is ---> is
# filled ---> fill
# with ---> with
# ambiguities ---> ambigu
# that ---> that
# make ---> make
# it ---> it
# incredibly ---> incred
# difficult ---> difficult
# to ---> to
# write ---> write
# software ---> softwar
# that ---> that
# accurately ---> accur
# determines ---> determin
# the ---> the
# intended ---> intend
# meaning ---> mean
# of ---> of
# text ---> text
# or ---> or
# voice ---> voic
# data ---> data
# . ---> .
# Homonyms ---> homonym
# , ---> ,
# homophones ---> homophon
# , ---> ,
# sarcasm ---> sarcasm
# , ---> ,
# idioms ---> idiom
# , ---> ,
# metaphors ---> metaphor
# , ---> ,
# grammar ---> grammar
# and ---> and
# usage ---> usag
# exceptions ---> except
# , ---> ,
# variations ---> variat
# in ---> in
# sentence ---> sentenc
# structure ---> structur
# . ---> .
# These ---> these
# just ---> just
# a ---> a
# few ---> few
# of ---> of
# the ---> the
# irregularities ---> irregular
# of ---> of
# human ---> human
# language ---> languag
# that ---> that
# take ---> take
# humans ---> human
# years ---> year
# to ---> to
# learn ---> learn
# , ---> ,
# but ---> but
# that ---> that
# programmers ---> programm
# must ---> must
# teach ---> teach
# natural ---> natur
# language ---> languag
# driven ---> driven
# applications ---> applic
# to ---> to
# recognize ---> recogn
# and ---> and
# understand ---> understand
# accurately ---> accur
# from ---> from
# the ---> the
# start ---> start
# if ---> if
# those ---> those
# applications ---> applic
# are ---> are
# going ---> go
# to ---> to
# be ---> be
# useful ---> use
# . ---> .

# %%
from nltk.stem.lancaster import LancasterStemmer
ls=LancasterStemmer()
for i in w:
  print(i,'--->',ls.stem(i))
# Out:
# Natural ---> nat
# language ---> langu
# processing ---> process
# refers ---> ref
# to ---> to
# the ---> the
# branch ---> branch
# of ---> of
# computer ---> comput
# science ---> sci
# and ---> and
# more ---> mor
# specifically ---> spec
# the ---> the
# branch ---> branch
# of ---> of
# artificial ---> art
# intelligence ---> intellig
# , ---> ,
# concerned ---> concern
# with ---> with
# giving ---> giv
# computers ---> comput
# the ---> the
# ability ---> abl
# to ---> to
# understand ---> understand
# text ---> text
# and ---> and
# spoken ---> spok
# words ---> word
# in ---> in
# much ---> much
# the ---> the
# same ---> sam
# way ---> way
# human ---> hum
# beings ---> being
# can ---> can
# . ---> .
# Human ---> hum
# language ---> langu
# is ---> is
# filled ---> fil
# with ---> with
# ambiguities ---> ambigu
# that ---> that
# make ---> mak
# it ---> it
# incredibly ---> incred
# difficult ---> difficult
# to ---> to
# write ---> writ
# software ---> softw
# that ---> that
# accurately ---> acc
# determines ---> determin
# the ---> the
# intended ---> intend
# meaning ---> mean
# of ---> of
# text ---> text
# or ---> or
# voice ---> voic
# data ---> dat
# . ---> .
# Homonyms ---> homonym
# , ---> ,
# homophones ---> homophon
# , ---> ,
# sarcasm ---> sarcasm
# , ---> ,
# idioms ---> idiom
# , ---> ,
# metaphors ---> metaph
# , ---> ,
# grammar ---> gramm
# and ---> and
# usage ---> us
# exceptions ---> exceiv
# , ---> ,
# variations ---> vary
# in ---> in
# sentence ---> sent
# structure ---> structure
# . ---> .
# These ---> thes
# just ---> just
# a ---> a
# few ---> few
# of ---> of
# the ---> the
# irregularities ---> irregul
# of ---> of
# human ---> hum
# language ---> langu
# that ---> that
# take ---> tak
# humans ---> hum
# years ---> year
# to ---> to
# learn ---> learn
# , ---> ,
# but ---> but
# that ---> that
# programmers ---> program
# must ---> must
# teach ---> teach
# natural ---> nat
# language ---> langu
# driven ---> driv
# applications ---> apply
# to ---> to
# recognize ---> recogn
# and ---> and
# understand ---> understand
# accurately ---> acc
# from ---> from
# the ---> the
# start ---> start
# if ---> if
# those ---> thos
# applications ---> apply
# are ---> ar
# going ---> going
# to ---> to
# be ---> be
# useful ---> us
# . ---> .

# %%
import spacy
# !pythom -m spacy download en_core_web_sm
nlp=spacy.load('en_core_web_sm')
doc=nlp(t)
for t in doc:
  print(t.text,'--->',t.lemma_)
# Out:
# /bin/bash: line 1: pythom: command not found
# Natural ---> natural
# language ---> language
# processing ---> processing
# refers ---> refer
# to ---> to
# the ---> the
# branch ---> branch
# of ---> of
#
#  --->
#
# computer ---> computer
# science ---> science
# and ---> and
# more ---> more
# specifically ---> specifically
# the ---> the
# branch ---> branch
# of ---> of
#
#  --->
#
# artificial ---> artificial
# intelligence ---> intelligence
# , ---> ,
# concerned ---> concern
# with ---> with
# giving ---> give
# computers ---> computer
#
#  --->
#
# the ---> the
# ability ---> ability
# to ---> to
# understand ---> understand
# text ---> text
# and ---> and
# spoken ---> spoken
# words ---> word
# in ---> in
# much ---> much
#
#  --->
#
# the ---> the
# same ---> same
# way ---> way
# human ---> human
# beings ---> being
# can ---> can
# . ---> .
# Human ---> human
# language ---> language
# is ---> be
# filled ---> fill
# with ---> with
#
#  --->
#
# ambiguities ---> ambiguity
# that ---> that
# make ---> make
# it ---> it
# incredibly ---> incredibly
# difficult ---> difficult
# to ---> to
# write ---> write
# software ---> software
#
#  --->
#
# that ---> that
# accurately ---> accurately
# determines ---> determine
# the ---> the
# intended ---> intend
# meaning ---> meaning
# of ---> of
# text ---> text
# or ---> or
# voice ---> voice
#
#  --->
#
# data ---> datum
# . ---> .
# Homonyms ---> Homonyms
# , ---> ,
# homophones ---> homophone
# , ---> ,
# sarcasm ---> sarcasm
# , ---> ,
# idioms ---> idiom
# , ---> ,
# metaphors ---> metaphor
# , ---> ,
# grammar ---> grammar
#
#  --->
#
# and ---> and
# usage ---> usage
# exceptions ---> exception
# , ---> ,
# variations ---> variation
# in ---> in
# sentence ---> sentence
# structure ---> structure
# . ---> .
# These ---> these
#
#  --->
#
# just ---> just
# a ---> a
# few ---> few
# of ---> of
# the ---> the
# irregularities ---> irregularity
# of ---> of
# human ---> human
# language ---> language
# that ---> that
# take ---> take
#
#  --->
#
# humans ---> human
# years ---> year
# to ---> to
# learn ---> learn
# , ---> ,
# but ---> but
# that ---> that
# programmers ---> programmer
# must ---> must
# teach ---> teach
# natural ---> natural
#
#  --->
#
# language ---> language
# driven ---> drive
# applications ---> application
# to ---> to
# recognize ---> recognize
# and ---> and
# understand ---> understand
#
#  --->
#
# accurately ---> accurately
# from ---> from
# the ---> the
# start ---> start
# if ---> if
# those ---> those
# applications ---> application
# are ---> be
# going ---> go
# to ---> to
# be ---> be
#
#  --->
#
# useful ---> useful
# . ---> .

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
wl=WordNetLemmatizer()
for i in w:
  print(i,'--->',wl.lemmatize(i))
# Out:
# Natural ---> Natural
# language ---> language
# processing ---> processing
# refers ---> refers
# to ---> to
# the ---> the
# branch ---> branch
# of ---> of
# computer ---> computer
# science ---> science
# and ---> and
# more ---> more
# specifically ---> specifically
# the ---> the
# branch ---> branch
# of ---> of
# artificial ---> artificial
# intelligence ---> intelligence
# , ---> ,
# concerned ---> concerned
# with ---> with
# giving ---> giving
# computers ---> computer
# the ---> the
# ability ---> ability
# to ---> to
# understand ---> understand
# text ---> text
# and ---> and
# spoken ---> spoken
# words ---> word
# in ---> in
# much ---> much
# the ---> the
# same ---> same
# way ---> way
# human ---> human
# beings ---> being
# can ---> can
# . ---> .
# Human ---> Human
# language ---> language
# is ---> is
# filled ---> filled
# with ---> with
# ambiguities ---> ambiguity
# that ---> that
# make ---> make
# it ---> it
# incredibly ---> incredibly
# difficult ---> difficult
# to ---> to
# write ---> write
# software ---> software
# that ---> that
# accurately ---> accurately
# determines ---> determines
# the ---> the
# intended ---> intended
# meaning ---> meaning
# of ---> of
# text ---> text
# or ---> or
# voice ---> voice
# data ---> data
# . ---> .
# Homonyms ---> Homonyms
# , ---> ,
# homophones ---> homophone
# , ---> ,
# sarcasm ---> sarcasm
# , ---> ,
# idioms ---> idiom
# , ---> ,
# metaphors ---> metaphor
# , ---> ,
# grammar ---> grammar
# and ---> and
# usage ---> usage
# exceptions ---> exception
# , ---> ,
# variations ---> variation
# in ---> in
# sentence ---> sentence
# structure ---> structure
# . ---> .
# These ---> These
# just ---> just
# a ---> a
# few ---> few
# of ---> of
# the ---> the
# irregularities ---> irregularity
# of ---> of
# human ---> human
# language ---> language
# that ---> that
# take ---> take
# humans ---> human
# years ---> year
# to ---> to
# learn ---> learn
# , ---> ,
# but ---> but
# that ---> that
# programmers ---> programmer
# must ---> must
# teach ---> teach
# natural ---> natural
# language ---> language
# driven ---> driven
# applications ---> application
# to ---> to
# recognize ---> recognize
# and ---> and
# understand ---> understand
# accurately ---> accurately
# from ---> from
# the ---> the
# start ---> start
# if ---> if
# those ---> those
# applications ---> application
# are ---> are
# going ---> going
# to ---> to
# be ---> be
# useful ---> useful
# . ---> .

# %%
from textblob import TextBlob
txts="""Natural language processing refers to the branch of
computer science and more specifically the branch of
artificial intelligence, concerned with giving computers
the ability to understand text and spoken words in much
the same way human beings can. Human language is filled with
ambiguities that make it incredibly difficult to write software
that accurately determines the intended meaning of text or voice
data. Homonyms, homophones,sarcasm, idioms, metaphors, grammar
and usage exceptions,variations in sentence structure. These
just a few of the irregularities of human language that take
humans years to learn, but that programmers must teach natural
language driven applications to recognize and understand
accurately from the start if those applications are going to be
useful."""
tb = TextBlob(txts)

for i in tb.words:
    print(i, '--->', i.lemmatize())
# Out:
# Natural ---> Natural
# language ---> language
# processing ---> processing
# refers ---> refers
# to ---> to
# the ---> the
# branch ---> branch
# of ---> of
# computer ---> computer
# science ---> science
# and ---> and
# more ---> more
# specifically ---> specifically
# the ---> the
# branch ---> branch
# of ---> of
# artificial ---> artificial
# intelligence ---> intelligence
# concerned ---> concerned
# with ---> with
# giving ---> giving
# computers ---> computer
# the ---> the
# ability ---> ability
# to ---> to
# understand ---> understand
# text ---> text
# and ---> and
# spoken ---> spoken
# words ---> word
# in ---> in
# much ---> much
# the ---> the
# same ---> same
# way ---> way
# human ---> human
# beings ---> being
# can ---> can
# Human ---> Human
# language ---> language
# is ---> is
# filled ---> filled
# with ---> with
# ambiguities ---> ambiguity
# that ---> that
# make ---> make
# it ---> it
# incredibly ---> incredibly
# difficult ---> difficult
# to ---> to
# write ---> write
# software ---> software
# that ---> that
# accurately ---> accurately
# determines ---> determines
# the ---> the
# intended ---> intended
# meaning ---> meaning
# of ---> of
# text ---> text
# or ---> or
# voice ---> voice
# data ---> data
# Homonyms ---> Homonyms
# homophones ---> homophone
# sarcasm ---> sarcasm
# idioms ---> idiom
# metaphors ---> metaphor
# grammar ---> grammar
# and ---> and
# usage ---> usage
# exceptions ---> exception
# variations ---> variation
# in ---> in
# sentence ---> sentence
# structure ---> structure
# These ---> These
# just ---> just
# a ---> a
# few ---> few
# of ---> of
# the ---> the
# irregularities ---> irregularity
# of ---> of
# human ---> human
# language ---> language
# that ---> that
# take ---> take
# humans ---> human
# years ---> year
# to ---> to
# learn ---> learn
# but ---> but
# that ---> that
# programmers ---> programmer
# must ---> must
# teach ---> teach
# natural ---> natural
# language ---> language
# driven ---> driven
# applications ---> application
# to ---> to
# recognize ---> recognize
# and ---> and
# understand ---> understand
# accurately ---> accurately
# from ---> from
# the ---> the
# start ---> start
# if ---> if
# those ---> those
# applications ---> application
# are ---> are
# going ---> going
# to ---> to
# be ---> be
# useful ---> useful
