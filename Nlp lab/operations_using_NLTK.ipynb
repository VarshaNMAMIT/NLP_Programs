# %%
import pandas as pd
df=pd.read_csv('ngram_tweets.csv',usecols=['text'])

# %%
import nltk
import re

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
l=WordNetLemmatizer()
s=stopwords.words('english')
words=df['text'].to_list()
words=' '.join(i.lower for i in words)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-e3179275d76a> in <cell line: 6>()
#       4 s=stopwords.words('english')
#       5 words=df['text'].to_list()
# ----> 6 words=' '.join(i.lower for i in words)
#
# TypeError: sequence item 0: expected str instance, builtin_function_or_method found
